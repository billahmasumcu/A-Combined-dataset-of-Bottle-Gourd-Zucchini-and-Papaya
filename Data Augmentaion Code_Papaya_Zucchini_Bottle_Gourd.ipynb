# %%
# prompt: mount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import time
import numpy as np
import cv2
from PIL import Image, ImageEnhance

# --- Google Drive Path Configuration ---
source_folder = r"D:\Assistant Professoor Masum Billal Sir\4 Dataset for Leaf Disease(Masum Billah Sir)\Agriculture Combined Dataset\Papaya Curled Yellow Spot"
target_folder = r"C:\Users\Sagor\Downloads\Output Papaya Curled Yellow Spot"
target_images = 1000  # desired total number of images

# --- Ensure Target Folder Exists ---
os.makedirs(target_folder, exist_ok=True)

# --- PIL-Based Augmentation (Color / Contrast / Brightness) ---
def augment_image_pil(image, count):
    brightness_factor = random.uniform(0.7, 1.3)
    contrast_factor = random.uniform(0.7, 1.3)
    color_factor = random.uniform(0.7, 1.3)

    enhanced_image = ImageEnhance.Color(
        ImageEnhance.Contrast(
            ImageEnhance.Brightness(image).enhance(brightness_factor)
        ).enhance(contrast_factor)
    ).enhance(color_factor)

    filename = f"aug_pil_{count}_b{brightness_factor:.2f}_c{contrast_factor:.2f}_col{color_factor:.2f}.jpg"
    return enhanced_image, filename


# --- OpenCV-Based Augmentation (Flipping, Rotation, Zooming, Noise, Shifting, Brightness) ---
def augment_image_cv2(image_path, count):
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not read image: {image_path}")

    height, width = image.shape[:2]
    augmented_images = []

    # === 1️⃣ Flipping ===
    augmented_images.append((cv2.flip(image, 1), f"cv2_flip_h_{count}.jpg"))  # Horizontal
    augmented_images.append((cv2.flip(image, 0), f"cv2_flip_v_{count}.jpg"))  # Vertical

    # === 2️⃣ Rotation ===
    for angle in [15, -15, 30, -30]:
        M = cv2.getRotationMatrix2D((width // 2, height // 2), angle, 1)
        rotated = cv2.warpAffine(image, M, (width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
        filename = f"cv2_rotate_{angle}_{count}.jpg"
        augmented_images.append((rotated, filename))

    # === 3️⃣ Zooming ===
    for zoom_factor in [0.8, 1.0, 1.2]:
        if zoom_factor == 1.0:
            zoomed = image.copy()
        elif zoom_factor > 1.0:
            zh, zw = int(height * zoom_factor), int(width * zoom_factor)
            zoomed_large = cv2.resize(image, (zw, zh), interpolation=cv2.INTER_LINEAR)
            start_x, start_y = (zw - width) // 2, (zh - height) // 2
            zoomed = zoomed_large[start_y:start_y + height, start_x:start_x + width]
        else:
            zh, zw = int(height * zoom_factor), int(width * zoom_factor)
            zoomed_small = cv2.resize(image, (zw, zh), interpolation=cv2.INTER_LINEAR)
            zoomed = np.zeros_like(image)
            start_x, start_y = (width - zw) // 2, (height - zh) // 2
            zoomed[start_y:start_y + zh, start_x:start_x + zw] = zoomed_small

        filename = f"cv2_zoom_{zoom_factor}_{count}.jpg"
        augmented_images.append((zoomed, filename))

    # === 4️⃣ Adding Gaussian Noise ===
    mean, stddev = 0, 10
    noise = np.random.normal(mean, stddev, image.shape).astype(np.float32)
    noisy_image = image.astype(np.float32) + noise
    noisy_image = np.clip(noisy_image, 0, 255).astype(np.uint8)
    filename = f"cv2_noisy_{count}.jpg"
    augmented_images.append((noisy_image, filename))

    # === 5️⃣ Shifting ===
    for dx, dy in [(10, 0), (-10, 0), (0, 10), (0, -10)]:
        M = np.float32([[1, 0, dx], [0, 1, dy]])
        shifted = cv2.warpAffine(image, M, (width, height), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)
        filename = f"cv2_shift_{dx}_{dy}_{count}.jpg"
        augmented_images.append((shifted, filename))

    # === 6️⃣ Brightness Adjustment ===
    for brightness_factor in [0.7, 1.3]:
        bright_img = cv2.convertScaleAbs(image, alpha=brightness_factor, beta=0)
        filename = f"cv2_brightness_{brightness_factor}_{count}.jpg"
        augmented_images.append((bright_img, filename))

    return augmented_images


# --- Manage Target Folder Limit ---
def manage_target_folder(folder, max_images):
    images = sorted(
        [f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))],
        key=lambda x: os.path.getctime(os.path.join(folder, x))
    )
    if len(images) > max_images:
        for img in images[max_images:]:
            os.remove(os.path.join(folder, img))


# --- Main Augmentation Pipeline ---
def main():
    print("🔍 Checking source folder...")
    if not os.path.isdir(source_folder):
        print(f"❌ Source folder not found: {source_folder}")
        return
    else:
        print(f"✅ Source folder found: {source_folder}")

    # List image files
    files_in_source = os.listdir(source_folder)
    print(f"📂 Total files found: {len(files_in_source)}")
    if files_in_source:
        print("🔸 Sample files:", files_in_source[:5])

    image_paths = [
        os.path.join(source_folder, f)
        for f in files_in_source
        if f.lower().endswith(('.jpg', '.jpeg', '.png'))
    ]

    if not image_paths:
        print("⚠️ No valid image files found (.jpg/.jpeg/.png).")
        return
    else:
        print(f"✅ Found {len(image_paths)} valid image(s) for augmentation.")

    random.shuffle(image_paths)

    start_time = time.time()
    current_count = len([f for f in os.listdir(target_folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
    print(f"🚀 Starting augmentation. Already in target: {current_count} images.")

    while current_count < target_images:
        for img_path in image_paths:
            if current_count >= target_images:
                break
            try:
                # --- PIL Augmentation ---
                with Image.open(img_path) as pil_image:
                    if pil_image.mode != "RGB":
                        pil_image = pil_image.convert("RGB")

                    pil_aug, pil_filename = augment_image_pil(pil_image, current_count)
                    pil_aug.save(os.path.join(target_folder, pil_filename), format="JPEG")
                    print(f"✅ Saved PIL image: {pil_filename}")
                    current_count += 1

                # --- OpenCV Augmentations ---
                cv2_augments = augment_image_cv2(img_path, current_count)
                for aug_img, filename in cv2_augments:
                    if current_count >= target_images:
                        break
                    cv2.imwrite(os.path.join(target_folder, filename), aug_img)
                    print(f"✅ Saved CV2 image: {filename}")
                    current_count += 1

            except Exception as e:
                print(f"⚠️ Error processing {img_path}: {e}")

    # --- Limit total images if exceeded ---
    manage_target_folder(target_folder, target_images)
    total = len(os.listdir(target_folder))
    print(f"\n✅ Augmentation complete. Total images: {total}")
    print(f"⏱ Time taken: {time.time() - start_time:.2f} seconds")


# --- Run Script ---
if __name__ == "__main__":
    main()
# Out:
# 🔍 Checking source folder...
# ✅ Source folder found: D:\Assistant Professoor Masum Billal Sir\4 Dataset for Leaf Disease(Masum Billah Sir)\Agriculture Combined Dataset\Papaya Curled Yellow Spot
# 📂 Total files found: 86
# 🔸 Sample files: ['IMG-20241027-WA0027-removebg-preview.png', 'IMG-20241027-WA0038-removebg-preview.png', 'IMG-20241027-WA0046-removebg-preview.png', 'IMG-20241027-WA0057-removebg-preview.png', 'IMG-20241027-WA0058-removebg-preview.png']
# ✅ Found 86 valid image(s) for augmentation.
# 🚀 Starting augmentation. Already in target: 0 images.
# ✅ Saved PIL image: aug_pil_0_b1.07_c0.74_col0.97.jpg
# ✅ Saved CV2 image: cv2_flip_h_1.jpg
# ✅ Saved CV2 image: cv2_flip_v_1.jpg
# ✅ Saved CV2 image: cv2_rotate_15_1.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_1.jpg
# ✅ Saved CV2 image: cv2_rotate_30_1.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_1.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_1.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_1.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_1.jpg
# ✅ Saved CV2 image: cv2_noisy_1.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_1.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_1.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_1.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_1.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_1.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_1.jpg
# ✅ Saved PIL image: aug_pil_17_b1.25_c1.15_col1.12.jpg
# ✅ Saved CV2 image: cv2_flip_h_18.jpg
# ✅ Saved CV2 image: cv2_flip_v_18.jpg
# ✅ Saved CV2 image: cv2_rotate_15_18.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_18.jpg
# ✅ Saved CV2 image: cv2_rotate_30_18.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_18.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_18.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_18.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_18.jpg
# ✅ Saved CV2 image: cv2_noisy_18.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_18.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_18.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_18.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_18.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_18.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_18.jpg
# ✅ Saved PIL image: aug_pil_34_b0.73_c1.09_col1.00.jpg
# ✅ Saved CV2 image: cv2_flip_h_35.jpg
# ✅ Saved CV2 image: cv2_flip_v_35.jpg
# ✅ Saved CV2 image: cv2_rotate_15_35.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_35.jpg
# ✅ Saved CV2 image: cv2_rotate_30_35.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_35.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_35.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_35.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_35.jpg
# ✅ Saved CV2 image: cv2_noisy_35.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_35.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_35.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_35.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_35.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_35.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_35.jpg
# ✅ Saved PIL image: aug_pil_51_b1.10_c1.25_col0.74.jpg
# ✅ Saved CV2 image: cv2_flip_h_52.jpg
# ✅ Saved CV2 image: cv2_flip_v_52.jpg
# ✅ Saved CV2 image: cv2_rotate_15_52.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_52.jpg
# ✅ Saved CV2 image: cv2_rotate_30_52.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_52.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_52.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_52.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_52.jpg
# ✅ Saved CV2 image: cv2_noisy_52.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_52.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_52.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_52.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_52.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_52.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_52.jpg
# ✅ Saved PIL image: aug_pil_68_b0.81_c0.81_col1.08.jpg
# ✅ Saved CV2 image: cv2_flip_h_69.jpg
# ✅ Saved CV2 image: cv2_flip_v_69.jpg
# ✅ Saved CV2 image: cv2_rotate_15_69.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_69.jpg
# ✅ Saved CV2 image: cv2_rotate_30_69.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_69.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_69.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_69.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_69.jpg
# ✅ Saved CV2 image: cv2_noisy_69.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_69.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_69.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_69.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_69.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_69.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_69.jpg
# ✅ Saved PIL image: aug_pil_85_b0.94_c1.29_col0.74.jpg
# ✅ Saved CV2 image: cv2_flip_h_86.jpg
# ✅ Saved CV2 image: cv2_flip_v_86.jpg
# ✅ Saved CV2 image: cv2_rotate_15_86.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_86.jpg
# ✅ Saved CV2 image: cv2_rotate_30_86.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_86.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_86.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_86.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_86.jpg
# ✅ Saved CV2 image: cv2_noisy_86.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_86.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_86.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_86.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_86.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_86.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_86.jpg
# ✅ Saved PIL image: aug_pil_102_b1.00_c1.20_col1.23.jpg
# ✅ Saved CV2 image: cv2_flip_h_103.jpg
# ✅ Saved CV2 image: cv2_flip_v_103.jpg
# ✅ Saved CV2 image: cv2_rotate_15_103.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_103.jpg
# ✅ Saved CV2 image: cv2_rotate_30_103.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_103.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_103.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_103.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_103.jpg
# ✅ Saved CV2 image: cv2_noisy_103.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_103.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_103.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_103.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_103.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_103.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_103.jpg
# ✅ Saved PIL image: aug_pil_119_b0.83_c0.76_col1.00.jpg
# ✅ Saved CV2 image: cv2_flip_h_120.jpg
# ✅ Saved CV2 image: cv2_flip_v_120.jpg
# ✅ Saved CV2 image: cv2_rotate_15_120.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_120.jpg
# ✅ Saved CV2 image: cv2_rotate_30_120.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_120.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_120.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_120.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_120.jpg
# ✅ Saved CV2 image: cv2_noisy_120.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_120.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_120.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_120.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_120.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_120.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_120.jpg
# ✅ Saved PIL image: aug_pil_136_b1.07_c1.18_col1.16.jpg
# ✅ Saved CV2 image: cv2_flip_h_137.jpg
# ✅ Saved CV2 image: cv2_flip_v_137.jpg
# ✅ Saved CV2 image: cv2_rotate_15_137.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_137.jpg
# ✅ Saved CV2 image: cv2_rotate_30_137.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_137.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_137.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_137.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_137.jpg
# ✅ Saved CV2 image: cv2_noisy_137.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_137.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_137.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_137.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_137.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_137.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_137.jpg
# ✅ Saved PIL image: aug_pil_153_b1.24_c1.01_col1.29.jpg
# ✅ Saved CV2 image: cv2_flip_h_154.jpg
# ✅ Saved CV2 image: cv2_flip_v_154.jpg
# ✅ Saved CV2 image: cv2_rotate_15_154.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_154.jpg
# ✅ Saved CV2 image: cv2_rotate_30_154.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_154.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_154.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_154.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_154.jpg
# ✅ Saved CV2 image: cv2_noisy_154.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_154.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_154.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_154.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_154.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_154.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_154.jpg
# ✅ Saved PIL image: aug_pil_170_b1.24_c1.18_col1.14.jpg
# ✅ Saved CV2 image: cv2_flip_h_171.jpg
# ✅ Saved CV2 image: cv2_flip_v_171.jpg
# ✅ Saved CV2 image: cv2_rotate_15_171.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_171.jpg
# ✅ Saved CV2 image: cv2_rotate_30_171.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_171.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_171.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_171.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_171.jpg
# ✅ Saved CV2 image: cv2_noisy_171.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_171.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_171.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_171.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_171.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_171.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_171.jpg
# ✅ Saved PIL image: aug_pil_187_b1.13_c0.91_col0.78.jpg
# ✅ Saved CV2 image: cv2_flip_h_188.jpg
# ✅ Saved CV2 image: cv2_flip_v_188.jpg
# ✅ Saved CV2 image: cv2_rotate_15_188.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_188.jpg
# ✅ Saved CV2 image: cv2_rotate_30_188.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_188.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_188.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_188.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_188.jpg
# ✅ Saved CV2 image: cv2_noisy_188.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_188.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_188.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_188.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_188.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_188.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_188.jpg
# ✅ Saved PIL image: aug_pil_204_b0.71_c1.24_col1.19.jpg
# ✅ Saved CV2 image: cv2_flip_h_205.jpg
# ✅ Saved CV2 image: cv2_flip_v_205.jpg
# ✅ Saved CV2 image: cv2_rotate_15_205.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_205.jpg
# ✅ Saved CV2 image: cv2_rotate_30_205.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_205.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_205.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_205.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_205.jpg
# ✅ Saved CV2 image: cv2_noisy_205.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_205.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_205.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_205.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_205.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_205.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_205.jpg
# ✅ Saved PIL image: aug_pil_221_b0.82_c0.72_col1.07.jpg
# ✅ Saved CV2 image: cv2_flip_h_222.jpg
# ✅ Saved CV2 image: cv2_flip_v_222.jpg
# ✅ Saved CV2 image: cv2_rotate_15_222.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_222.jpg
# ✅ Saved CV2 image: cv2_rotate_30_222.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_222.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_222.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_222.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_222.jpg
# ✅ Saved CV2 image: cv2_noisy_222.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_222.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_222.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_222.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_222.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_222.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_222.jpg
# ✅ Saved PIL image: aug_pil_238_b1.14_c1.11_col1.01.jpg
# ✅ Saved CV2 image: cv2_flip_h_239.jpg
# ✅ Saved CV2 image: cv2_flip_v_239.jpg
# ✅ Saved CV2 image: cv2_rotate_15_239.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_239.jpg
# ✅ Saved CV2 image: cv2_rotate_30_239.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_239.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_239.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_239.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_239.jpg
# ✅ Saved CV2 image: cv2_noisy_239.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_239.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_239.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_239.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_239.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_239.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_239.jpg
# ✅ Saved PIL image: aug_pil_255_b0.84_c0.92_col0.78.jpg
# ✅ Saved CV2 image: cv2_flip_h_256.jpg
# ✅ Saved CV2 image: cv2_flip_v_256.jpg
# ✅ Saved CV2 image: cv2_rotate_15_256.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_256.jpg
# ✅ Saved CV2 image: cv2_rotate_30_256.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_256.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_256.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_256.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_256.jpg
# ✅ Saved CV2 image: cv2_noisy_256.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_256.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_256.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_256.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_256.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_256.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_256.jpg
# ✅ Saved PIL image: aug_pil_272_b0.72_c0.81_col0.94.jpg
# ✅ Saved CV2 image: cv2_flip_h_273.jpg
# ✅ Saved CV2 image: cv2_flip_v_273.jpg
# ✅ Saved CV2 image: cv2_rotate_15_273.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_273.jpg
# ✅ Saved CV2 image: cv2_rotate_30_273.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_273.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_273.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_273.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_273.jpg
# ✅ Saved CV2 image: cv2_noisy_273.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_273.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_273.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_273.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_273.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_273.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_273.jpg
# ✅ Saved PIL image: aug_pil_289_b1.03_c1.24_col0.99.jpg
# ✅ Saved CV2 image: cv2_flip_h_290.jpg
# ✅ Saved CV2 image: cv2_flip_v_290.jpg
# ✅ Saved CV2 image: cv2_rotate_15_290.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_290.jpg
# ✅ Saved CV2 image: cv2_rotate_30_290.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_290.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_290.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_290.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_290.jpg
# ✅ Saved CV2 image: cv2_noisy_290.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_290.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_290.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_290.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_290.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_290.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_290.jpg
# ✅ Saved PIL image: aug_pil_306_b0.90_c1.23_col0.79.jpg
# ✅ Saved CV2 image: cv2_flip_h_307.jpg
# ✅ Saved CV2 image: cv2_flip_v_307.jpg
# ✅ Saved CV2 image: cv2_rotate_15_307.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_307.jpg
# ✅ Saved CV2 image: cv2_rotate_30_307.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_307.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_307.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_307.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_307.jpg
# ✅ Saved CV2 image: cv2_noisy_307.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_307.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_307.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_307.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_307.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_307.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_307.jpg
# ✅ Saved PIL image: aug_pil_323_b1.27_c1.30_col1.10.jpg
# ✅ Saved CV2 image: cv2_flip_h_324.jpg
# ✅ Saved CV2 image: cv2_flip_v_324.jpg
# ✅ Saved CV2 image: cv2_rotate_15_324.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_324.jpg
# ✅ Saved CV2 image: cv2_rotate_30_324.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_324.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_324.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_324.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_324.jpg
# ✅ Saved CV2 image: cv2_noisy_324.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_324.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_324.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_324.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_324.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_324.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_324.jpg
# ✅ Saved PIL image: aug_pil_340_b0.72_c1.10_col0.90.jpg
# ✅ Saved CV2 image: cv2_flip_h_341.jpg
# ✅ Saved CV2 image: cv2_flip_v_341.jpg
# ✅ Saved CV2 image: cv2_rotate_15_341.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_341.jpg
# ✅ Saved CV2 image: cv2_rotate_30_341.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_341.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_341.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_341.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_341.jpg
# ✅ Saved CV2 image: cv2_noisy_341.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_341.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_341.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_341.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_341.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_341.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_341.jpg
# ✅ Saved PIL image: aug_pil_357_b0.76_c0.85_col0.73.jpg
# ✅ Saved CV2 image: cv2_flip_h_358.jpg
# ✅ Saved CV2 image: cv2_flip_v_358.jpg
# ✅ Saved CV2 image: cv2_rotate_15_358.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_358.jpg
# ✅ Saved CV2 image: cv2_rotate_30_358.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_358.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_358.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_358.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_358.jpg
# ✅ Saved CV2 image: cv2_noisy_358.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_358.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_358.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_358.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_358.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_358.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_358.jpg
# ✅ Saved PIL image: aug_pil_374_b0.86_c1.12_col0.84.jpg
# ✅ Saved CV2 image: cv2_flip_h_375.jpg
# ✅ Saved CV2 image: cv2_flip_v_375.jpg
# ✅ Saved CV2 image: cv2_rotate_15_375.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_375.jpg
# ✅ Saved CV2 image: cv2_rotate_30_375.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_375.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_375.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_375.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_375.jpg
# ✅ Saved CV2 image: cv2_noisy_375.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_375.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_375.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_375.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_375.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_375.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_375.jpg
# ✅ Saved PIL image: aug_pil_391_b1.18_c1.20_col1.04.jpg
# ✅ Saved CV2 image: cv2_flip_h_392.jpg
# ✅ Saved CV2 image: cv2_flip_v_392.jpg
# ✅ Saved CV2 image: cv2_rotate_15_392.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_392.jpg
# ✅ Saved CV2 image: cv2_rotate_30_392.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_392.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_392.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_392.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_392.jpg
# ✅ Saved CV2 image: cv2_noisy_392.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_392.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_392.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_392.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_392.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_392.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_392.jpg
# ✅ Saved PIL image: aug_pil_408_b0.85_c1.03_col0.71.jpg
# ✅ Saved CV2 image: cv2_flip_h_409.jpg
# ✅ Saved CV2 image: cv2_flip_v_409.jpg
# ✅ Saved CV2 image: cv2_rotate_15_409.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_409.jpg
# ✅ Saved CV2 image: cv2_rotate_30_409.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_409.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_409.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_409.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_409.jpg
# ✅ Saved CV2 image: cv2_noisy_409.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_409.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_409.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_409.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_409.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_409.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_409.jpg
# ✅ Saved PIL image: aug_pil_425_b0.81_c1.30_col1.22.jpg
# ✅ Saved CV2 image: cv2_flip_h_426.jpg
# ✅ Saved CV2 image: cv2_flip_v_426.jpg
# ✅ Saved CV2 image: cv2_rotate_15_426.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_426.jpg
# ✅ Saved CV2 image: cv2_rotate_30_426.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_426.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_426.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_426.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_426.jpg
# ✅ Saved CV2 image: cv2_noisy_426.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_426.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_426.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_426.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_426.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_426.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_426.jpg
# ✅ Saved PIL image: aug_pil_442_b1.11_c1.03_col1.23.jpg
# ✅ Saved CV2 image: cv2_flip_h_443.jpg
# ✅ Saved CV2 image: cv2_flip_v_443.jpg
# ✅ Saved CV2 image: cv2_rotate_15_443.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_443.jpg
# ✅ Saved CV2 image: cv2_rotate_30_443.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_443.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_443.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_443.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_443.jpg
# ✅ Saved CV2 image: cv2_noisy_443.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_443.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_443.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_443.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_443.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_443.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_443.jpg
# ✅ Saved PIL image: aug_pil_459_b0.95_c0.92_col0.75.jpg
# ✅ Saved CV2 image: cv2_flip_h_460.jpg
# ✅ Saved CV2 image: cv2_flip_v_460.jpg
# ✅ Saved CV2 image: cv2_rotate_15_460.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_460.jpg
# ✅ Saved CV2 image: cv2_rotate_30_460.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_460.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_460.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_460.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_460.jpg
# ✅ Saved CV2 image: cv2_noisy_460.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_460.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_460.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_460.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_460.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_460.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_460.jpg
# ✅ Saved PIL image: aug_pil_476_b0.71_c0.79_col1.04.jpg
# ✅ Saved CV2 image: cv2_flip_h_477.jpg
# ✅ Saved CV2 image: cv2_flip_v_477.jpg
# ✅ Saved CV2 image: cv2_rotate_15_477.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_477.jpg
# ✅ Saved CV2 image: cv2_rotate_30_477.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_477.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_477.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_477.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_477.jpg
# ✅ Saved CV2 image: cv2_noisy_477.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_477.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_477.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_477.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_477.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_477.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_477.jpg
# ✅ Saved PIL image: aug_pil_493_b1.22_c0.72_col0.87.jpg
# ✅ Saved CV2 image: cv2_flip_h_494.jpg
# ✅ Saved CV2 image: cv2_flip_v_494.jpg
# ✅ Saved CV2 image: cv2_rotate_15_494.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_494.jpg
# ✅ Saved CV2 image: cv2_rotate_30_494.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_494.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_494.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_494.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_494.jpg
# ✅ Saved CV2 image: cv2_noisy_494.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_494.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_494.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_494.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_494.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_494.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_494.jpg
# ✅ Saved PIL image: aug_pil_510_b0.92_c1.20_col0.93.jpg
# ✅ Saved CV2 image: cv2_flip_h_511.jpg
# ✅ Saved CV2 image: cv2_flip_v_511.jpg
# ✅ Saved CV2 image: cv2_rotate_15_511.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_511.jpg
# ✅ Saved CV2 image: cv2_rotate_30_511.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_511.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_511.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_511.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_511.jpg
# ✅ Saved CV2 image: cv2_noisy_511.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_511.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_511.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_511.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_511.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_511.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_511.jpg
# ✅ Saved PIL image: aug_pil_527_b1.13_c1.27_col1.19.jpg
# ✅ Saved CV2 image: cv2_flip_h_528.jpg
# ✅ Saved CV2 image: cv2_flip_v_528.jpg
# ✅ Saved CV2 image: cv2_rotate_15_528.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_528.jpg
# ✅ Saved CV2 image: cv2_rotate_30_528.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_528.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_528.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_528.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_528.jpg
# ✅ Saved CV2 image: cv2_noisy_528.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_528.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_528.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_528.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_528.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_528.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_528.jpg
# ✅ Saved PIL image: aug_pil_544_b1.27_c1.03_col0.88.jpg
# ✅ Saved CV2 image: cv2_flip_h_545.jpg
# ✅ Saved CV2 image: cv2_flip_v_545.jpg
# ✅ Saved CV2 image: cv2_rotate_15_545.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_545.jpg
# ✅ Saved CV2 image: cv2_rotate_30_545.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_545.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_545.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_545.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_545.jpg
# ✅ Saved CV2 image: cv2_noisy_545.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_545.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_545.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_545.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_545.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_545.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_545.jpg
# ✅ Saved PIL image: aug_pil_561_b0.97_c1.26_col0.87.jpg
# ✅ Saved CV2 image: cv2_flip_h_562.jpg
# ✅ Saved CV2 image: cv2_flip_v_562.jpg
# ✅ Saved CV2 image: cv2_rotate_15_562.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_562.jpg
# ✅ Saved CV2 image: cv2_rotate_30_562.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_562.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_562.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_562.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_562.jpg
# ✅ Saved CV2 image: cv2_noisy_562.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_562.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_562.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_562.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_562.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_562.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_562.jpg
# ✅ Saved PIL image: aug_pil_578_b1.29_c0.81_col0.72.jpg
# ✅ Saved CV2 image: cv2_flip_h_579.jpg
# ✅ Saved CV2 image: cv2_flip_v_579.jpg
# ✅ Saved CV2 image: cv2_rotate_15_579.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_579.jpg
# ✅ Saved CV2 image: cv2_rotate_30_579.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_579.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_579.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_579.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_579.jpg
# ✅ Saved CV2 image: cv2_noisy_579.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_579.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_579.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_579.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_579.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_579.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_579.jpg
# ✅ Saved PIL image: aug_pil_595_b0.76_c0.97_col0.73.jpg
# ✅ Saved CV2 image: cv2_flip_h_596.jpg
# ✅ Saved CV2 image: cv2_flip_v_596.jpg
# ✅ Saved CV2 image: cv2_rotate_15_596.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_596.jpg
# ✅ Saved CV2 image: cv2_rotate_30_596.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_596.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_596.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_596.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_596.jpg
# ✅ Saved CV2 image: cv2_noisy_596.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_596.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_596.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_596.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_596.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_596.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_596.jpg
# ✅ Saved PIL image: aug_pil_612_b0.79_c0.79_col1.18.jpg
# ✅ Saved CV2 image: cv2_flip_h_613.jpg
# ✅ Saved CV2 image: cv2_flip_v_613.jpg
# ✅ Saved CV2 image: cv2_rotate_15_613.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_613.jpg
# ✅ Saved CV2 image: cv2_rotate_30_613.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_613.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_613.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_613.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_613.jpg
# ✅ Saved CV2 image: cv2_noisy_613.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_613.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_613.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_613.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_613.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_613.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_613.jpg
# ✅ Saved PIL image: aug_pil_629_b1.25_c1.02_col1.09.jpg
# ✅ Saved CV2 image: cv2_flip_h_630.jpg
# ✅ Saved CV2 image: cv2_flip_v_630.jpg
# ✅ Saved CV2 image: cv2_rotate_15_630.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_630.jpg
# ✅ Saved CV2 image: cv2_rotate_30_630.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_630.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_630.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_630.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_630.jpg
# ✅ Saved CV2 image: cv2_noisy_630.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_630.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_630.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_630.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_630.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_630.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_630.jpg
# ✅ Saved PIL image: aug_pil_646_b0.98_c1.15_col1.19.jpg
# ✅ Saved CV2 image: cv2_flip_h_647.jpg
# ✅ Saved CV2 image: cv2_flip_v_647.jpg
# ✅ Saved CV2 image: cv2_rotate_15_647.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_647.jpg
# ✅ Saved CV2 image: cv2_rotate_30_647.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_647.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_647.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_647.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_647.jpg
# ✅ Saved CV2 image: cv2_noisy_647.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_647.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_647.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_647.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_647.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_647.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_647.jpg
# ✅ Saved PIL image: aug_pil_663_b1.03_c1.01_col0.86.jpg
# ✅ Saved CV2 image: cv2_flip_h_664.jpg
# ✅ Saved CV2 image: cv2_flip_v_664.jpg
# ✅ Saved CV2 image: cv2_rotate_15_664.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_664.jpg
# ✅ Saved CV2 image: cv2_rotate_30_664.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_664.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_664.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_664.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_664.jpg
# ✅ Saved CV2 image: cv2_noisy_664.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_664.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_664.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_664.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_664.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_664.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_664.jpg
# ✅ Saved PIL image: aug_pil_680_b0.77_c1.06_col0.92.jpg
# ✅ Saved CV2 image: cv2_flip_h_681.jpg
# ✅ Saved CV2 image: cv2_flip_v_681.jpg
# ✅ Saved CV2 image: cv2_rotate_15_681.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_681.jpg
# ✅ Saved CV2 image: cv2_rotate_30_681.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_681.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_681.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_681.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_681.jpg
# ✅ Saved CV2 image: cv2_noisy_681.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_681.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_681.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_681.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_681.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_681.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_681.jpg
# ✅ Saved PIL image: aug_pil_697_b1.30_c0.83_col1.16.jpg
# ✅ Saved CV2 image: cv2_flip_h_698.jpg
# ✅ Saved CV2 image: cv2_flip_v_698.jpg
# ✅ Saved CV2 image: cv2_rotate_15_698.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_698.jpg
# ✅ Saved CV2 image: cv2_rotate_30_698.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_698.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_698.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_698.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_698.jpg
# ✅ Saved CV2 image: cv2_noisy_698.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_698.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_698.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_698.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_698.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_698.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_698.jpg
# ✅ Saved PIL image: aug_pil_714_b1.03_c1.08_col1.20.jpg
# ✅ Saved CV2 image: cv2_flip_h_715.jpg
# ✅ Saved CV2 image: cv2_flip_v_715.jpg
# ✅ Saved CV2 image: cv2_rotate_15_715.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_715.jpg
# ✅ Saved CV2 image: cv2_rotate_30_715.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_715.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_715.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_715.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_715.jpg
# ✅ Saved CV2 image: cv2_noisy_715.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_715.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_715.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_715.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_715.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_715.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_715.jpg
# ✅ Saved PIL image: aug_pil_731_b0.88_c0.78_col0.74.jpg
# ✅ Saved CV2 image: cv2_flip_h_732.jpg
# ✅ Saved CV2 image: cv2_flip_v_732.jpg
# ✅ Saved CV2 image: cv2_rotate_15_732.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_732.jpg
# ✅ Saved CV2 image: cv2_rotate_30_732.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_732.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_732.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_732.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_732.jpg
# ✅ Saved CV2 image: cv2_noisy_732.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_732.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_732.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_732.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_732.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_732.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_732.jpg
# ✅ Saved PIL image: aug_pil_748_b1.25_c1.00_col0.79.jpg
# ✅ Saved CV2 image: cv2_flip_h_749.jpg
# ✅ Saved CV2 image: cv2_flip_v_749.jpg
# ✅ Saved CV2 image: cv2_rotate_15_749.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_749.jpg
# ✅ Saved CV2 image: cv2_rotate_30_749.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_749.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_749.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_749.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_749.jpg
# ✅ Saved CV2 image: cv2_noisy_749.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_749.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_749.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_749.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_749.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_749.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_749.jpg
# ✅ Saved PIL image: aug_pil_765_b1.29_c0.86_col1.06.jpg
# ✅ Saved CV2 image: cv2_flip_h_766.jpg
# ✅ Saved CV2 image: cv2_flip_v_766.jpg
# ✅ Saved CV2 image: cv2_rotate_15_766.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_766.jpg
# ✅ Saved CV2 image: cv2_rotate_30_766.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_766.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_766.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_766.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_766.jpg
# ✅ Saved CV2 image: cv2_noisy_766.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_766.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_766.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_766.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_766.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_766.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_766.jpg
# ✅ Saved PIL image: aug_pil_782_b1.07_c0.76_col1.30.jpg
# ✅ Saved CV2 image: cv2_flip_h_783.jpg
# ✅ Saved CV2 image: cv2_flip_v_783.jpg
# ✅ Saved CV2 image: cv2_rotate_15_783.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_783.jpg
# ✅ Saved CV2 image: cv2_rotate_30_783.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_783.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_783.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_783.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_783.jpg
# ✅ Saved CV2 image: cv2_noisy_783.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_783.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_783.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_783.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_783.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_783.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_783.jpg
# ✅ Saved PIL image: aug_pil_799_b0.97_c0.93_col1.27.jpg
# ✅ Saved CV2 image: cv2_flip_h_800.jpg
# ✅ Saved CV2 image: cv2_flip_v_800.jpg
# ✅ Saved CV2 image: cv2_rotate_15_800.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_800.jpg
# ✅ Saved CV2 image: cv2_rotate_30_800.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_800.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_800.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_800.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_800.jpg
# ✅ Saved CV2 image: cv2_noisy_800.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_800.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_800.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_800.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_800.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_800.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_800.jpg
# ✅ Saved PIL image: aug_pil_816_b0.86_c1.06_col0.92.jpg
# ✅ Saved CV2 image: cv2_flip_h_817.jpg
# ✅ Saved CV2 image: cv2_flip_v_817.jpg
# ✅ Saved CV2 image: cv2_rotate_15_817.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_817.jpg
# ✅ Saved CV2 image: cv2_rotate_30_817.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_817.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_817.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_817.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_817.jpg
# ✅ Saved CV2 image: cv2_noisy_817.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_817.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_817.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_817.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_817.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_817.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_817.jpg
# ✅ Saved PIL image: aug_pil_833_b1.20_c0.74_col1.00.jpg
# ✅ Saved CV2 image: cv2_flip_h_834.jpg
# ✅ Saved CV2 image: cv2_flip_v_834.jpg
# ✅ Saved CV2 image: cv2_rotate_15_834.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_834.jpg
# ✅ Saved CV2 image: cv2_rotate_30_834.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_834.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_834.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_834.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_834.jpg
# ✅ Saved CV2 image: cv2_noisy_834.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_834.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_834.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_834.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_834.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_834.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_834.jpg
# ✅ Saved PIL image: aug_pil_850_b1.14_c0.90_col0.73.jpg
# ✅ Saved CV2 image: cv2_flip_h_851.jpg
# ✅ Saved CV2 image: cv2_flip_v_851.jpg
# ✅ Saved CV2 image: cv2_rotate_15_851.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_851.jpg
# ✅ Saved CV2 image: cv2_rotate_30_851.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_851.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_851.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_851.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_851.jpg
# ✅ Saved CV2 image: cv2_noisy_851.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_851.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_851.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_851.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_851.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_851.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_851.jpg
# ✅ Saved PIL image: aug_pil_867_b0.86_c1.30_col0.81.jpg
# ✅ Saved CV2 image: cv2_flip_h_868.jpg
# ✅ Saved CV2 image: cv2_flip_v_868.jpg
# ✅ Saved CV2 image: cv2_rotate_15_868.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_868.jpg
# ✅ Saved CV2 image: cv2_rotate_30_868.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_868.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_868.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_868.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_868.jpg
# ✅ Saved CV2 image: cv2_noisy_868.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_868.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_868.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_868.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_868.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_868.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_868.jpg
# ✅ Saved PIL image: aug_pil_884_b1.15_c1.06_col0.74.jpg
# ✅ Saved CV2 image: cv2_flip_h_885.jpg
# ✅ Saved CV2 image: cv2_flip_v_885.jpg
# ✅ Saved CV2 image: cv2_rotate_15_885.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_885.jpg
# ✅ Saved CV2 image: cv2_rotate_30_885.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_885.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_885.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_885.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_885.jpg
# ✅ Saved CV2 image: cv2_noisy_885.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_885.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_885.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_885.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_885.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_885.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_885.jpg
# ✅ Saved PIL image: aug_pil_901_b1.08_c1.22_col1.29.jpg
# ✅ Saved CV2 image: cv2_flip_h_902.jpg
# ✅ Saved CV2 image: cv2_flip_v_902.jpg
# ✅ Saved CV2 image: cv2_rotate_15_902.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_902.jpg
# ✅ Saved CV2 image: cv2_rotate_30_902.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_902.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_902.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_902.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_902.jpg
# ✅ Saved CV2 image: cv2_noisy_902.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_902.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_902.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_902.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_902.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_902.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_902.jpg
# ✅ Saved PIL image: aug_pil_918_b0.88_c0.83_col0.81.jpg
# ✅ Saved CV2 image: cv2_flip_h_919.jpg
# ✅ Saved CV2 image: cv2_flip_v_919.jpg
# ✅ Saved CV2 image: cv2_rotate_15_919.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_919.jpg
# ✅ Saved CV2 image: cv2_rotate_30_919.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_919.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_919.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_919.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_919.jpg
# ✅ Saved CV2 image: cv2_noisy_919.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_919.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_919.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_919.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_919.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_919.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_919.jpg
# ✅ Saved PIL image: aug_pil_935_b1.29_c1.24_col0.73.jpg
# ✅ Saved CV2 image: cv2_flip_h_936.jpg
# ✅ Saved CV2 image: cv2_flip_v_936.jpg
# ✅ Saved CV2 image: cv2_rotate_15_936.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_936.jpg
# ✅ Saved CV2 image: cv2_rotate_30_936.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_936.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_936.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_936.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_936.jpg
# ✅ Saved CV2 image: cv2_noisy_936.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_936.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_936.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_936.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_936.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_936.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_936.jpg
# ✅ Saved PIL image: aug_pil_952_b1.07_c1.15_col1.18.jpg
# ✅ Saved CV2 image: cv2_flip_h_953.jpg
# ✅ Saved CV2 image: cv2_flip_v_953.jpg
# ✅ Saved CV2 image: cv2_rotate_15_953.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_953.jpg
# ✅ Saved CV2 image: cv2_rotate_30_953.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_953.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_953.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_953.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_953.jpg
# ✅ Saved CV2 image: cv2_noisy_953.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_953.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_953.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_953.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_953.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_953.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_953.jpg
# ✅ Saved PIL image: aug_pil_969_b1.29_c0.89_col1.13.jpg
# ✅ Saved CV2 image: cv2_flip_h_970.jpg
# ✅ Saved CV2 image: cv2_flip_v_970.jpg
# ✅ Saved CV2 image: cv2_rotate_15_970.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_970.jpg
# ✅ Saved CV2 image: cv2_rotate_30_970.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_970.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_970.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_970.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_970.jpg
# ✅ Saved CV2 image: cv2_noisy_970.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_970.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_970.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_970.jpg
# ✅ Saved CV2 image: cv2_shift_0_-10_970.jpg
# ✅ Saved CV2 image: cv2_brightness_0.7_970.jpg
# ✅ Saved CV2 image: cv2_brightness_1.3_970.jpg
# ✅ Saved PIL image: aug_pil_986_b1.03_c0.90_col0.99.jpg
# ✅ Saved CV2 image: cv2_flip_h_987.jpg
# ✅ Saved CV2 image: cv2_flip_v_987.jpg
# ✅ Saved CV2 image: cv2_rotate_15_987.jpg
# ✅ Saved CV2 image: cv2_rotate_-15_987.jpg
# ✅ Saved CV2 image: cv2_rotate_30_987.jpg
# ✅ Saved CV2 image: cv2_rotate_-30_987.jpg
# ✅ Saved CV2 image: cv2_zoom_0.8_987.jpg
# ✅ Saved CV2 image: cv2_zoom_1.0_987.jpg
# ✅ Saved CV2 image: cv2_zoom_1.2_987.jpg
# ✅ Saved CV2 image: cv2_noisy_987.jpg
# ✅ Saved CV2 image: cv2_shift_10_0_987.jpg
# ✅ Saved CV2 image: cv2_shift_-10_0_987.jpg
# ✅ Saved CV2 image: cv2_shift_0_10_987.jpg
#
# ✅ Augmentation complete. Total images: 1000
# ⏱ Time taken: 10.71 seconds
